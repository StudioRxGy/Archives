// %%
// 逐仓可用=max(0,钱包余额-∑逐仓仓位保证金-∑全仓仓位保证金-∑逐仓委托冻结保证金-∑全仓委托冻结保证金&预扣手续费+min(0,∑全仓所有仓位未实现盈亏))
double result = Math.Max(0, 98.01 - 64.26075 - 16.18075 + Math.Min(0, -15.65));

Console.WriteLine($"逐仓可用结果: {result}");

// %%
// 强平价=(钱包余额-多仓的开仓价值)/-[合约乘数*合约数量*(1-仓位的维持保证金率)]
double resultAUD = (18.58 - 0.65404 * 0.01 * 100000) / -(100000 * 0.01 * (1 - 0.004));

Console.WriteLine($"AUD强平价结果: {resultAUD}");

// %%
// 委托数量 * 最新价格 * 合约乘数 / 杠杆
double resultGBP = 0.03 * 1.35321 * 100000 / 100;
double resultXAG = 0.02 * 72.299 * 5000/ 100;

Console.WriteLine($"GBP计算的值是: {resultGBP}");
Console.WriteLine($"XAG计算的值是: {resultXAG}");

// %%
// 全仓可用余额减少 = 委托数量 * 委托价格 * 合约乘数 * take手续费配置 * Vip折扣 + 委托数量 * 委托价格 * 合约乘数 / 杠杆
double resultAUD = 0.01 * 0.67065 * 100000 * 0.00003 * 0.95 + 0.01 * 0.67065 * 100000 / 500;

Console.WriteLine($"AUD计算的值是: {resultAUD}");

// %%
// 强平价=(钱包余额-多仓的开仓价值)/-[合约乘数*合约数量*(1-仓位的维持保证金率)]
double result = (53.7 - 26853.2) / -(100000 * 0.04 * (1 - 0.001));
double resule1 = (99.98 - 670.63) / -(100000 * 0.01 * (1 - 0.001));

Console.WriteLine($"第一个强平价结果: {result}");
Console.WriteLine($"第二个强平价结果: {resule1}");

// %%
// # 保证金率 = ((钱包余额-∑全仓委托冻结保证金&预扣手续费)+∑全仓未实盈亏)/∑所有全仓仓位维持保证金(合约乘数*手数*最新价格*维持保证金率)
double result = ((53.70 - 0) + 4.40) / (100000 * 0.04 * 0.67145 * 0.001);
double resultA = ((99.93 - 0) + (-0.02)) / (100000 * 0.01 * 1.17769 * 0.008);
double resuleB = ((99.98-0)+0.02) / (100000 * 0.01 * 0.67065 * 0.001);

Console.WriteLine($"第一个保证金率结果: {result}");
Console.WriteLine($"第二个保证金率结果: {resultA}");
Console.WriteLine($"第三个保证金率结果: {resuleB}");

// %%
// 全仓可转出=max(0,钱包余额-∑逐仓仓位保证金-∑全仓仓位占用-∑逐仓委托冻结保证金-∑全仓委托冻结保证金&预扣手续费+min(0，∑全仓所有仓位未实现盈亏))
double result1 = Math.Max(0, 98.01 - 64.26075 - 16.18075 + Math.Min(0, -15.65));
double result2 = Math.Max(0, 38.93 - 0 - 50 - 0 - 0 + Math.Min(0, 11.96));
double result3 = Math.Max(0, 30.92 - 0 - 32.07 - 0 - 0 + Math.Min(0, 1.15));

Console.WriteLine($"第一个全仓可转出结果: {result1}");
Console.WriteLine($"第二个全仓可转出结果: {result2}");
Console.WriteLine($"第三个全仓可转出结果: {result3}");

// %%
// 可开数量=用户可用余额/(下单价格(市价单=最新价*(1+浮动比例))*合约乘数*((1/杠杆)+taker手续费率*VIP折扣))
double result = 100 / (0.67123 * 1.0001 * 100000 * ((1.0/500.0) + 0.00003 * 0.0095));

Console.WriteLine($"可开数量结果: {result}");

// %%
// 全仓可用=max(0,钱包余额-∑逐仓仓位保证金-∑全仓仓位保证金-∑逐仓委托冻结保证金-∑全仓委托冻结保证金&预扣手续费+∑全仓所有仓位未实现盈亏)
double result = Math.Max(0, 98.01 - 64.26075 - 16.18075 + (-15.65));
double result2 = Math.Max(0, 38.93 - 0 - 50 - 0 - 0 + 11.96);

Console.WriteLine($"第一个全仓可用结果: {result}");
Console.WriteLine($"第二个全仓可用结果: {result2}");
