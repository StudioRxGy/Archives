# %% [markdown]
# 1. 平均付款时间=付款用总时长/单数
#     商家买入广告付款时间:5/1=5
#     用户付款=3/1
# 2. 平均放行时间=放行用总时长/单数
#     商家放行=4/1

# %% [markdown]
# #### 2026/1/19 市场沟通问题记录
# 1. 关闭代理后身份变为直客
# 2. 直客单独设置比例
# 3. 代理和用户表单备注同步
# 4. 代理层级展示备注
# 5. 代理层级区分直客和代理
# 6. 交易记录统计和筛选条件联动 增加出入金、资金权益、持仓量
# 7. 代理表单增加团队人数(代理人数,直客人数)
# 8. 代理表单增加展开列表 展示对应的下级
# 9. 代理表单返佣金额分为总创造的金额 当前代理拿到多少钱
# 11. 代理展示做市比例标签展示
# 12. 首页数据概览需要添加跳转对应代理表单和用户表单 交易人数增加报表 交易人数展示所有的交易人数(增加持仓量)
