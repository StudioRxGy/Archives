# %%
# 可开数量=用户可用余额/(下单价格(市价单=最新价*(1+浮动比例))*合约乘数*((1/杠杆)+taker手续费率*VIP折扣))
result1 = 100 / (0.64719 * 1.0001 * 100000 * ((1/100) + 0.00075 * 1))
result2 = 100 / (0.64951 * 1.0001 * 100000 * ((1/100) + 0.00075 * 1))

print(f"{result1}")
print(f"{result2}")

# %%
result = max(0,98.01-64.26075-16.18075-0-0+min(0,-15.65))

print(f"{result}")

# %%
result = max(0, 37.24 - 10.29968 - 9.70725 - 9.70725 - 0 - 0 + min(0, 30.45 + (-23.85)))

print(f"{result}")

# %%
result = 86.67476/((1*0.075)+(1.28506*(1.0001)*100000)/20)

print(f"{result}")

# %%
# 逐仓可用=max（0，钱包余额-∑逐仓仓位保证金-∑全仓仓位保证金-∑逐仓委托冻结保证金-∑全仓委托冻结保证金&预扣手续费+min（0，∑全仓所有仓位未实现盈亏）)
result = max(0,98.01-64.26075-16.18075-0-0+min(0,-15.65))

print(f"{result}")

# %%
# 强平价=(钱包余额-多仓的开仓价值)/-[合约乘数*合约数量*(1-仓位的维持保证金率)]
result = (199.99-1.17871*0.01*100000)/-(100000*0.01*(1-0.004))

print(f"{result}")

# %%
# 成交额(成交价值) = 成交价格 * 成交数量 * 合约乘数
result = 0.65399 * 0.01 * 100000

print(f"{result}")

# %%
# 成交数量 * 标记价格 * 合约乘数 / 杠杆
result1 = 0.01 * 1.17869 * 100000 / 50
result2 = 0.01 * 0.1 * 100000 / 50

print(f"{result1}")
print(f"{result2}")

# %%
# 保证金率 = ((钱包余额-∑逐仓仓位保证金-∑逐仓委托冻结保证金-∑全仓委托冻结保证金&预扣手续费)+∑全仓未实盈亏)/∑所有全仓仓位维持保证金(合约乘数*手数*最新价格*维持保证金率)
result = ((45.70 - 0 - 0 - 0) + 4.92) / (100000 * 0.03 * 4512.54 * 0.001)

print(f"{result}")
