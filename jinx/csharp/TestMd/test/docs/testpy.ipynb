# %%
result = 100 / (0.64719 * 1.0001 * 100000 * (1/100) + 0.00075 * 1)

print(f"{result}")
# Out:
# 0.15449850142556304

# %%
result = max(0,98.01-64.26075-16.18075-0-0+min(0,-15.65))

print(f"{result}")
# Out:
# 1.9185000000000034

# %%
result = max(0, 37.24 - 10.29968 - 9.70725 - 9.70725 - 0 - 0 + min(0, 30.45 + (-23.85)))

print(f"{result}")
# Out:
# 7.525819999999998

# %%
result = 86.67476/((1*0.075)+(1.28506*(1.0001)*100000)/20)

print(f"{result}")
# Out:
# 0.013488098903458796

# %%
# 逐仓可用=max（0，钱包余额-∑逐仓仓位保证金-∑全仓仓位保证金-∑逐仓委托冻结保证金-∑全仓委托冻结保证金&预扣手续费+min（0，∑全仓所有仓位未实现盈亏）)
result = max(0,98.01-64.26075-16.18075-0-0+min(0,-15.65))

print(f"{result}")
# Out:
# 1.9185000000000034

# %%
# 强平价=(钱包余额-多仓的开仓价值)/-[合约乘数*合约数量*(1-仓位的维持保证金率)]
result = (18.58-0.65404*0.01*100000)/-(100000*0.01*(1-0.004))

print(f"{result}")
# Out:
# 0.638012048192771

# %%
# 成交额(成交价值) = 成交价格 * 成交数量 * 合约乘数
result = 0.65399 * 0.01 * 100000

print(f"{result}")
# Out:
# 653.99
